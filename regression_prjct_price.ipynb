# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Bengaluru_price_prediction.csv")
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0     2   39.07  2.0
# 1              Chikka Tirupathi  4 Bedroom      2600.0     5  120.00  NaN
# 2                   Uttarahalli      3 BHK      1440.0     2   62.00  3.0
# 3            Lingadheeranahalli      3 BHK      1521.0     3   95.00  3.0
# 4                      Kothanur      2 BHK      1200.0     2   51.00  2.0
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0     4  231.00  5.0
# 13196                     other      4 BHK      3600.0     5  400.00  4.0
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.00  2.0
# 13198           Padmanabhanagar      4 BHK      4689.0     4  488.00  4.0
# 13199              Doddathoguru      1 BHK       550.0     1   17.00  1.0
#
#        price_per_sqft
# 0              3699.0
# 1              4615.0
# ...

# %%
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0     2   39.07  2.0
# 1          Chikka Tirupathi  4 Bedroom      2600.0     5  120.00  NaN
# 2               Uttarahalli      3 BHK      1440.0     2   62.00  3.0
# 3        Lingadheeranahalli      3 BHK      1521.0     3   95.00  3.0
# 4                  Kothanur      2 BHK      1200.0     2   51.00  2.0
#
#    price_per_sqft
# 0          3699.0
# 1          4615.0
# 2          4305.0
# 3          6245.0
# 4          4250.0

# %%
df.tail()
# Out:
#                     location       size  total_sqft  bath  price  bhk  \
# 13195             Whitefield  5 Bedroom      3453.0     4  231.0  5.0
# 13196                  other      4 BHK      3600.0     5  400.0  4.0
# 13197  Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.0  2.0
# 13198        Padmanabhanagar      4 BHK      4689.0     4  488.0  4.0
# 13199           Doddathoguru      1 BHK       550.0     1   17.0  1.0
#
#        price_per_sqft
# 13195          6689.0
# 13196         11111.0
# 13197          5258.0
# 13198         10407.0
# 13199          3090.0

# %%
df.dtypes
# Out:
# location           object
# size               object
# total_sqft        float64
# bath                int64
# price             float64
# bhk               float64
# price_per_sqft    float64
# dtype: object

# %%
df.shape
# Out:
# (13200, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        13200 non-null  object
#  1   size            13200 non-null  object
#  2   total_sqft      13200 non-null  float64
#  3   bath            13200 non-null  int64
#  4   price           13200 non-null  float64
#  5   bhk             13197 non-null  float64
#  6   price_per_sqft  13194 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 722.0+ KB

# %%
df.columns
# Out:
# Index(['location', 'size', 'total_sqft', 'bath', 'price', 'bhk',
#        'price_per_sqft'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# location          0
# size              0
# total_sqft        0
# bath              0
# price             0
# bhk               3
# price_per_sqft    6
# dtype: int64

# %%
# Assuming 'data' is your dataset and 'column_name' is the column you want to find unique counts for
unique_count = df['location'].nunique()
print("Unique count:", unique_count)
# Out:
# Unique count: 241

# %%
unique_count = df['size'].nunique()
print("Unique count:", unique_count)
# Out:
# Unique count: 31

# %%
df['size'].value_counts()
# Out:
# size
# 2 BHK         5192
# 3 BHK         4277
# 4 Bedroom      816
# 4 BHK          574
# 3 Bedroom      541
# 1 BHK          527
# 2 Bedroom      325
# 5 Bedroom      293
# 6 Bedroom      190
# 1 Bedroom      100
# 7 Bedroom       83
# 8 Bedroom       83
# 5 BHK           56
# 9 Bedroom       45
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            7
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
sns.countplot(y=df['size'])
# Out:
# <Axes: xlabel='count', ylabel='size'>

# %%
df['total_sqft'].value_counts()
# Out:
# total_sqft
# 1200.0    843
# 1100.0    221
# 1500.0    204
# 2400.0    195
# 600.0     180
#          ...
# 904.0       1
# 396.0       1
# 4273.0      1
# 3329.0      1
# 4689.0      1
# Name: count, Length: 1972, dtype: int64

# %%
df['bath'].value_counts()
# Out:
# bath
# 2     6893
# 3     3274
# 4     1222
# 1      781
# 5      521
# 6      269
# 7      102
# 8       64
# 9       41
# 10      13
# 12       7
# 13       3
# 11       3
# 16       2
# 27       1
# 40       1
# 15       1
# 14       1
# 18       1
# Name: count, dtype: int64

# %%
sns.countplot(y=df['bath'])
# Out:
# <Axes: xlabel='count', ylabel='bath'>

# %%
df['bhk'].value_counts()
# Out:
# bhk
# 2.0     5516
# 3.0     4818
# 4.0     1388
# 1.0      640
# 5.0      349
# 6.0      220
# 7.0      100
# 8.0       88
# 9.0       52
# 10.0      14
# 11.0       4
# 27.0       1
# 19.0       1
# 16.0       1
# 43.0       1
# 14.0       1
# 12.0       1
# 13.0       1
# 18.0       1
# Name: count, dtype: int64

# %%
sns.countplot(y=df['bhk'])
# Out:
# <Axes: xlabel='count', ylabel='bhk'>

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# 5000.0     148
# 4000.0     139
# 3500.0     109
# 10000.0     77
# 5500.0      74
#           ...
# 11272.0      1
# 11337.0      1
# 9589.0       1
# 4729.0       1
# 10407.0      1
# Name: count, Length: 4951, dtype: int64

# %%
df.drop(['location'],axis=1,inplace=True)

# %%
df['bhk']=df['bhk'].fillna(df['bhk'].mean())
df['price_per_sqft']=df['price_per_sqft'].fillna(df['price_per_sqft'].mean())

# %%
df.isna().sum()
# Out:
# size              0
# total_sqft        0
# bath              0
# price             0
# bhk               0
# price_per_sqft    0
# dtype: int64

# %%
#replace string in the data

df['size'] = df['size'].str.replace('BHK', '')
df['size'] = df['size'].str.replace('Bedroom', '')
df['size'] = df['size'].str.replace('RK', '')
df
# Out:
#       size  total_sqft  bath   price       bhk  price_per_sqft
# 0       2       1056.0     2   39.07  2.000000          3699.0
# 1       4       2600.0     5  120.00  2.800712          4615.0
# 2       3       1440.0     2   62.00  3.000000          4305.0
# 3       3       1521.0     3   95.00  3.000000          6245.0
# 4       2       1200.0     2   51.00  2.000000          4250.0
# ...    ...         ...   ...     ...       ...             ...
# 13195   5       3453.0     4  231.00  5.000000          6689.0
# 13196   4       3600.0     5  400.00  4.000000         11111.0
# 13197   2       1141.0     2   60.00  2.000000          5258.0
# 13198   4       4689.0     4  488.00  4.000000         10407.0
# 13199   1        550.0     1   17.00  1.000000          3090.0
#
# [13200 rows x 6 columns]

# %%
# to change data type

df['size']=df['size'].astype(int)

# %%
df.dtypes
# Out:
# size                int64
# total_sqft        float64
# bath                int64
# price             float64
# bhk               float64
# price_per_sqft    float64
# dtype: object

# %%
sns.boxplot(x=df['size'],data=df)
# Out:
# <Axes: xlabel='size'>

# %%
sns.boxplot(x=df['total_sqft'],data=df)
# Out:
# <Axes: xlabel='total_sqft'>

# %%
sns.boxplot(x=df['bath'],data=df)
# Out:
# <Axes: xlabel='bath'>

# %%
sns.boxplot(x=df['bhk'],data=df)
# Out:
# <Axes: xlabel='bhk'>

# %%
sns.boxplot(x=df['price_per_sqft'],data=df)
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_outliers_removed = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_outliers_removed

for col in ['size','total_sqft','bath','bhk','price_per_sqft']:
    df = remove_outliers_iqr(df, col)

# %%
sns.boxplot(x=df['size'],data=df)
# Out:
# <Axes: xlabel='size'>

# %%
sns.boxplot(x=df['total_sqft'],data=df)
# Out:
# <Axes: xlabel='total_sqft'>

# %%
sns.boxplot(x=df['bath'],data=df)
# Out:
# <Axes: xlabel='bath'>

# %%
sns.boxplot(x=df['bhk'],data=df)
# Out:
# <Axes: xlabel='bhk'>

# %%
sns.boxplot(x=df['price_per_sqft'],data=df)
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
#display the correlation of the data

df.corr()
# Out:
#                     size  total_sqft      bath     price       bhk  \
# size            1.000000    0.716354  0.779633  0.550313  0.999925
# total_sqft      0.716354    1.000000  0.729830  0.791075  0.716306
# bath            0.779633    0.729830  1.000000  0.618098  0.779585
# price           0.550313    0.791075  0.618098  1.000000  0.550294
# bhk             0.999925    0.716306  0.779585  0.550294  1.000000
# price_per_sqft  0.216181    0.291604  0.290411  0.786506  0.216208
#
#                 price_per_sqft
# size                  0.216181
# total_sqft            0.291604
# bath                  0.290411
# price                 0.786506
# bhk                   0.216208
# price_per_sqft        1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.drop(['size'],axis=1,inplace=True)

# %%
sns.regplot(x=df['total_sqft'],y=df['price'],line_kws={'color': 'k'})
# Out:
# <Axes: xlabel='total_sqft', ylabel='price'>

# %%
sns.regplot(x=df['bath'],y=df['price'],color='k')
# Out:
# <Axes: xlabel='bath', ylabel='price'>

# %%
sns.regplot(x=df['bhk'],y=df['price'],color='green')
# Out:
# <Axes: xlabel='bhk', ylabel='price'>

# %%
sns.regplot(x=df['price_per_sqft'],y=df['price'],color='red',line_kws={'color': 'k'})
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='price'>

# %%
x=df.drop(['price'],axis=1)         # fetches all columns except price
x
# Out:
#        total_sqft  bath  bhk  price_per_sqft
# 0          1056.0     2  2.0          3699.0
# 2          1440.0     2  3.0          4305.0
# 3          1521.0     3  3.0          6245.0
# 4          1200.0     2  2.0          4250.0
# 5          1170.0     2  2.0          3247.0
# ...           ...   ...  ...             ...
# 13192      1262.0     2  2.0          3724.0
# 13193      1345.0     2  3.0          4237.0
# 13194      1715.0     3  3.0          6530.0
# 13197      1141.0     2  2.0          5258.0
# 13199       550.0     1  1.0          3090.0
#
# [10427 rows x 4 columns]

# %%
y=df['price']
y
# Out:
# 0         39.07
# 2         62.00
# 3         95.00
# 4         51.00
# 5         38.00
#           ...
# 13192     47.00
# 13193     57.00
# 13194    112.00
# 13197     60.00
# 13199     17.00
# Name: price, Length: 10427, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#        total_sqft  bath  bhk  price_per_sqft
# 6980       1219.0     2  2.0          5025.0
# 5279       1290.0     2  2.0          9302.0
# 12793       845.0     2  2.0          4023.0
# 6512       1320.0     2  3.0          2888.0
# 1743       1420.0     2  2.0          9577.0
# ...           ...   ...  ...             ...
# 7232       1015.0     2  2.0          4926.0
# 6556       1855.0     3  3.0          7816.0
# 6805       1110.0     2  2.0          3599.0
# 1073       1340.0     2  3.0          3606.0
# 9182       1160.0     2  2.0          6465.0
#
# [7298 rows x 4 columns]

# %%
x_test
# Out:
#        total_sqft  bath  bhk  price_per_sqft
# 13090      1500.0     2  3.0          5200.0
# 8335       2317.0     4  3.0          6042.0
# 2660       1050.0     2  2.0          4000.0
# 8044       1243.0     2  2.0          3700.0
# 5338       1001.0     2  2.0          2997.0
# ...           ...   ...  ...             ...
# 10040      2140.0     3  3.0          6495.0
# 7348        935.0     2  2.0          3800.0
# 9426       1092.0     2  2.0          3937.0
# 5859       1340.0     3  3.0          4047.0
# 3100       1325.0     2  2.0          3773.0
#
# [3129 rows x 4 columns]

# %%
y_train
# Out:
# 6980      61.26
# 5279     120.00
# 12793     34.00
# 6512      38.13
# 1743     136.00
#           ...
# 7232      50.00
# 6556     145.00
# 6805      39.95
# 1073      48.33
# 9182      75.00
# Name: price, Length: 7298, dtype: float64

# %%
y_test
# Out:
# 13090     78.00
# 8335     140.00
# 2660      42.00
# 8044      46.00
# 5338      30.00
#           ...
# 10040    139.00
# 7348      35.53
# 9426      43.00
# 5859      54.24
# 3100      50.00
# Name: price, Length: 3129, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[-0.22375815, -0.41701952, -0.63325217, -0.1391361 ],
#        [-0.02957389, -0.41701952, -0.63325217,  2.57294946],
#        [-1.24664429, -0.41701952, -0.63325217, -0.77451363],
#        ...,
#        [-0.52187203, -0.41701952, -0.63325217, -1.04337598],
#        [ 0.1071756 , -0.41701952,  0.92763449, -1.03893722],
#        [-0.38512254, -0.41701952, -0.63325217,  0.77398132]])

# %%
x_test
# Out:
# array([[ 0.54477394, -0.41701952,  0.92763449, -0.02816697],
#        [ 2.7792605 ,  2.79671696,  0.92763449,  0.50575308],
#        [-0.68597141, -0.41701952, -0.63325217, -0.78909815],
#        ...,
#        [-0.57110184, -0.41701952, -0.63325217, -0.82904703],
#        [ 0.1071756 ,  1.18984872,  0.92763449, -0.75929501],
#        [ 0.06615075, -0.41701952, -0.63325217, -0.93304096]])

# %% [markdown]
# # **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 79.40274953, 140.60266626,  39.40583117, ...,  41.08983518,
#         55.21267791,  52.87779919])

# %%
df1=pd.DataFrame({'actual value':y_test,'predicted value':y_pred,'difference':y_test-y_pred})
df1
# Out:
#        actual value  predicted value  difference
# 13090         78.00        79.402750   -1.402750
# 8335         140.00       140.602666   -0.602666
# 2660          42.00        39.405831    2.594169
# 8044          46.00        47.005792   -1.005792
# 5338          30.00        23.247891    6.752109
# ...             ...              ...         ...
# 10040        139.00       135.386523    3.613477
# 7348          35.53        29.883588    5.646412
# 9426          43.00        41.089835    1.910165
# 5859          54.24        55.212678   -0.972678
# 3100          50.00        52.877799   -2.877799
#
# [3129 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,r2_score
print("MAE is",mean_absolute_error(y_test,y_pred))
print("MAPE is",mean_absolute_percentage_error(y_test,y_pred))
print("MSE is",mean_squared_error(y_test,y_pred))
print("R2 score is",r2_score(y_test,y_pred))
# Out:
# MAE is 4.100329818678251
# MAPE is 0.08468413520444719
# MSE is 43.89539206158446
# R2 score is 0.9631842797379263

# %% [markdown]
# # **RandomForestRegressor**

# %%
from sklearn.ensemble import RandomForestRegressor
model1=RandomForestRegressor()
model1.fit(x_train,y_train)
y_pred1=model1.predict(x_test)
y_pred1
# Out:
# array([ 77.8207, 137.5   ,  42.005 , ...,  43.0149,  54.2172,  50.0524])

# %%
df2=pd.DataFrame({'actual value':y_test,'predicted value':y_pred1,'difference':y_test-y_pred1})
df2
# Out:
#        actual value  predicted value  difference
# 13090         78.00          77.8207      0.1793
# 8335         140.00         137.5000      2.5000
# 2660          42.00          42.0050     -0.0050
# 8044          46.00          46.0000      0.0000
# 5338          30.00          30.0279     -0.0279
# ...             ...              ...         ...
# 10040        139.00         136.7800      2.2200
# 7348          35.53          35.3841      0.1459
# 9426          43.00          43.0149     -0.0149
# 5859          54.24          54.2172      0.0228
# 3100          50.00          50.0524     -0.0524
#
# [3129 rows x 3 columns]

# %%
print("MAE is",mean_absolute_error(y_test,y_pred1))
print("MAPE is",mean_absolute_percentage_error(y_test,y_pred1))
print("MSE is",mean_squared_error(y_test,y_pred1))
print("R2 score is",r2_score(y_test,y_pred1))
# Out:
# MAE is 0.377245160205283
# MAPE is 0.006371426222597543
# MSE is 2.8537871470673437
# R2 score is 0.9976064861398999

# %% [markdown]
# # **XGBRegressor**

# %%
from xgboost import XGBRegressor
model2=XGBRegressor()
model2.fit(x_train,y_train)
y_pred2=model2.predict(x_test)
y_pred2
# Out:
# array([ 76.99168 , 138.2099  ,  42.283066, ...,  42.812763,  54.54866 ,
#         49.682816], dtype=float32)

# %%
df3=pd.DataFrame({'actual value':y_test,'predicted value':y_pred2,'difference':y_test-y_pred2})
df3
# Out:
#        actual value  predicted value  difference
# 13090         78.00        76.991676    1.008324
# 8335         140.00       138.209900    1.790100
# 2660          42.00        42.283066   -0.283066
# 8044          46.00        45.941986    0.058014
# 5338          30.00        29.724161    0.275839
# ...             ...              ...         ...
# 10040        139.00       138.479721    0.520279
# 7348          35.53        35.426697    0.103303
# 9426          43.00        42.812763    0.187237
# 5859          54.24        54.548660   -0.308660
# 3100          50.00        49.682816    0.317184
#
# [3129 rows x 3 columns]

# %%
print("MAE is",mean_absolute_error(y_test,y_pred2))
print("MAPE is",mean_absolute_percentage_error(y_test,y_pred2))
print("MSE is",mean_squared_error(y_test,y_pred2))
print("R2 score is",r2_score(y_test,y_pred2))
# Out:
# MAE is 0.6402508585153581
# MAPE is 0.01082087580377183
# MSE is 3.2575556579535228
# R2 score is 0.9972678394654023
